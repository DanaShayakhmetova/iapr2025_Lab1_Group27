# %% [markdown]
# Author: Zhuoran
# Chocolates: arabia, passion, triangolo, noblesse

# %%
from src.find_mask import FindMask
from src.visulization import Visualization
from src.utils import *

find_mask = FindMask()

# %% [markdown]
# *Arabia*
# <img src="../images/Arabia.jpg" width="700">

# %% [markdown]
# For this kind of chocolate, my plans are listed below:
# 1. Use the find_circle function in the skimage package
# 2. Use the hsv plus find_contours method( You could find the code in the mixing.py)

# %% [markdown]
# *Noblesse*
# <img src="../images/Noblesse.jpg" width="700">

# %% [markdown]
# For this image, my plan is also to mix the hsv threshold methon in combination with the find_contours method.

# %% [markdown]
# *Passion_au_lait*
# <img src="../images/Passion_au_lait.JPG" width="700">

# %% [markdown]
# For this kind of chocolate, we just use the hsv threshold method to disringuish the little inner heart shape in the middle of this chocolate, the reasons are listed below:
# 1. First, we can see that the inner heart has a relatively even surface which meas that it is less easily affected by the light reflection that other chocolates.
# 2. The inner heart pattern is naturally surrowed by the brown outline, so this makes it isolated naturally from the background.

# %%
image_path  = "../images/Passion_au_lait.JPG"
image = read_image(image_path)
hsv = find_mask.to_hsv(image)
Visualization.show_image(hsv, "hsv")

# %% [markdown]
# *Triangolo*
# <img src = "../images/Triangolo.JPG" width = "700">

# %% [markdown]
# For this chocolate, we use the mixing method(hsv plus find_contours)
